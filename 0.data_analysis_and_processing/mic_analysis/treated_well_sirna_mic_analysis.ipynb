# %% [markdown]
# # Evaluate Well Stain Relationship Strength
# This analysis compares Maximal Information Coefficient (MIC) scores between the same DAPI and GOLD aggregated well features per well.
# Distributions of these MIC scores are visualized, between zero and one, where one indicates a perfect relationship and zero indicates no relationship.

# %%
import pathlib
import re
import sys

import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

# %% [markdown]
# ## Find the root of the git repo on the host system

# %%
# Get the current working directory
cwd = pathlib.Path.cwd()

if (cwd / ".git").is_dir():
    root_dir = cwd

else:
    root_dir = None
    for parent in cwd.parents:
        if (parent / ".git").is_dir():
            root_dir = parent
            break

# Check if a Git root directory was found
if root_dir is None:
    raise FileNotFoundError("No Git root directory found.")

# %% [markdown]
# # Custom Imports

# %%
sys.path.append(f"{root_dir}/0.data_analysis_and_processing/utils")

from MIC import MIC
from PairwiseCompare import PairwiseCompare
from ShuffledMIC import ShuffledMIC

# %% [markdown]
# # Inputs

# %%
# Paths to original nuclear speckle data
data_dir = root_dir / "nuclear_speckles_data"
nuclear_mask_dir = (data_dir / "Nuclear_masks").resolve(strict=True)
sc_profiles_path = list((data_dir / "Preprocessed_data/single_cell_profiles").resolve(strict=True).glob("*feature_selected*.parquet"))

# Load single-cell profile data
scdfs = [pd.read_parquet(sc_path) for sc_path in sc_profiles_path if sc_path.is_file()]

# %% [markdown]
# # Outputs

# %%
distribution_figures_path = pathlib.Path("treated_well_sirna_mic_distribution_figures")
distribution_figures_path.mkdir(parents=True, exist_ok=True)

mic_comparisons_path = pathlib.Path("mic_comparisons_data")
mic_comparisons_path.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# # Processing

# %% [markdown]
# ## Combine Common Data
# Column names are used to combine common single-cell data.

# %%
common_columns = scdfs[0].columns
for scdf in scdfs[1:]:
    common_columns = common_columns.intersection(scdf.columns)

scdfs = pd.concat(scdfs, axis=0)[common_columns]

# %% [markdown]
# ## Retain Useful Morphologies

# %%
scdfs.dropna(inplace=True)

# We aren't analyzing the other nuclear speckle stain (A647)
# Bounding Box features don't describe cell morphologies
scdfs = scdfs.drop(columns=[col for col in scdfs.columns if "BoundingBox" in col])

# %%
print(scdfs)
# Out:
#       Metadata_CellLine Metadata_Condition  Metadata_ImageNumber  \
# 0                  786O                NTC                     1
# 1                  786O                NTC                     1
# 2                  786O                NTC                     1
# 3                  786O                NTC                     1
# 4                  786O                NTC                     1
# ...                 ...                ...                   ...
# 63354              293T          untreated                   407
# 63355              293T          untreated                   407
# 63356              293T          untreated                   407
# 63357              293T          untreated                   407
# 63358              293T          untreated                   407
#
#       Metadata_Plate Metadata_Well Metadata_Site  Metadata_Nuclei_Site_Count  \
# 0             slide3            A1           M14                          40
# 1             slide3            A1           M14                          40
# 2             slide3            A1           M14                          40
# 3             slide3            A1           M14                          40
# 4             slide3            A1           M14                          40
# ...              ...           ...           ...                         ...
# 63354         slide4            B4            M9                         856
# 63355         slide4            B4            M9                         856
# 63356         slide4            B4            M9                         856
# 63357         slide4            B4            M9                         856
# 63358         slide4            B4            M9                         856
#
#        Metadata_Nuclei_Location_Center_X  Metadata_Nuclei_Location_Center_Y  \
# 0                             440.421603                          78.968641
# 1                             419.490134                         104.726914
# 2                             228.128582                        1150.712626
# 3                             193.636493                        1293.612259
# 4                             238.685272                        1344.190989
# ...                                  ...                                ...
# 63354                         259.852031                        2265.419729
# 63355                        1031.180619                        2264.759513
# 63356                         738.728900                        2267.087809
# 63357                        2272.609593                        2271.556609
# 63358                         824.547855                        2280.754675
#
#        Nuclei_AreaShape_Area  ...  Nuclei_Texture_Correlation_DAPI_3_02_256  \
# 0                  -0.455396  ...                                  0.076553
# 1                  -0.768349  ...                                  0.440507
# 2                   1.681257  ...                                  0.442093
# 3                  -0.515006  ...                                 -0.204978
# 4                  -0.358529  ...                                 -0.196367
# ...                      ...  ...                                       ...
# 63354              -1.231858  ...                                 -1.567802
# 63355               0.397688  ...                                  0.873889
# 63356              -0.990121  ...                                  0.239501
# 63357               0.088127  ...                                  0.637374
# 63358              -1.449246  ...                                 -0.091024
#
#        Nuclei_Texture_Correlation_DAPI_3_03_256  \
# 0                                     -0.955255
# 1                                     -0.935149
# 2                                     -0.002420
# 3                                     -1.124243
# 4                                     -1.294883
# ...                                         ...
# 63354                                 -1.402389
# 63355                                  0.957832
# 63356                                 -0.726772
# 63357                                  0.329904
# 63358                                 -0.500739
#
#        Nuclei_Texture_Correlation_GOLD_3_00_256  \
# 0                                     -4.683966
# 1                                     -4.683966
# 2                                      0.477625
# 3                                     -0.895212
# 4                                     -1.379071
# ...                                         ...
# 63354                                 -1.699914
# 63355                                  0.256921
# 63356                                 -1.723400
# 63357                                 -0.938126
# 63358                                 -0.604331
#
#        Nuclei_Texture_Correlation_GOLD_3_01_256  \
# 0                                     -2.873172
# 1                                     -2.873172
# 2                                      0.364749
# 3                                     -1.471390
# 4                                     -0.299818
# ...                                         ...
# 63354                                 -0.362258
# 63355                                  1.081944
# 63356                                 -1.670593
# 63357                                 -0.337367
# 63358                                 -0.373327
#
#        Nuclei_Texture_Correlation_GOLD_3_02_256  \
# 0                                     -4.635442
# 1                                     -4.635442
# 2                                      0.057439
# 3                                     -0.572905
# 4                                     -0.971546
# ...                                         ...
# 63354                                 -0.952431
# 63355                                  0.885690
# 63356                                 -1.738772
# 63357                                 -0.740371
# 63358                                 -1.485818
#
#        Nuclei_Texture_Correlation_GOLD_3_03_256  \
# 0                                     -2.869097
# 1                                     -2.869097
# 2                                      0.136200
# 3                                      0.140653
# 4                                     -2.075405
# ...                                         ...
# 63354                                 -1.934467
# 63355                                  0.074114
# 63356                                 -1.688474
# 63357                                 -0.793532
# 63358                                 -0.784130
#
#        Nuclei_Texture_InfoMeas1_DAPI_3_00_256  \
# 0                                    0.535714
# 1                                    0.924185
# 2                                   -0.671712
# 3                                    0.708704
# 4                                    0.974129
# ...                                       ...
# 63354                                1.362543
# 63355                               -0.979198
# 63356                                0.486452
# 63357                               -0.346221
# 63358                               -0.147601
#
#        Nuclei_Texture_InfoMeas1_DAPI_3_01_256  \
# 0                                   -0.182047
# 1                                   -0.823399
# 2                                   -0.987276
# 3                                    0.449238
# 4                                   -1.009551
# ...                                       ...
# 63354                                1.128533
# 63355                               -0.663974
# 63356                               -0.761964
# 63357                               -0.534778
# 63358                                0.065643
#
#        Nuclei_Texture_InfoMeas1_DAPI_3_02_256  \
# 0                                    0.502261
# 1                                    0.023690
# 2                                   -0.664844
# 3                                    0.741110
# 4                                    0.464294
# ...                                       ...
# 63354                                1.162664
# 63355                               -1.025852
# 63356                               -1.088521
# 63357                               -1.008774
# 63358                                0.261785
#
#        Nuclei_Texture_InfoMeas1_DAPI_3_03_256
# 0                                    0.791409
# 1                                   -0.008731
# 2                                    0.026038
# 3                                    1.011587
# 4                                    1.326281
# ...                                       ...
# 63354                                1.229538
# 63355                               -0.825447
# 63356                                0.597475
# 63357                               -0.252631
# 63358                                0.245148
#
# [240906 rows x 267 columns]

# %% [markdown]
# ## Seperate Gold and Dapi Features

# %%
gold_scdfs = scdfs.loc[:, ~scdfs.columns.str.contains("DAPI|A647", regex=True)]
a647_scdfs = scdfs.loc[:, ~scdfs.columns.str.contains("DAPI|GOLD", regex=True)]
dapi_scdfs = scdfs.loc[:, ~scdfs.columns.str.contains("A647|GOLD", regex=True)]

gold_scdfs.columns = gold_scdfs.columns.str.replace('_GOLD', '', regex=False)
a647_scdfs.columns = gold_scdfs.columns.str.replace('_A647', '', regex=False)
dapi_scdfs.columns = dapi_scdfs.columns.str.replace('_DAPI', '', regex=False)

# %% [markdown]
# ## Combine Seperated Stain Features

# %%
gold_scdfs = gold_scdfs.assign(Metadata_Stain="GOLD")
dapi_scdfs = dapi_scdfs.assign(Metadata_Stain="DAPI")
a647_scdfs = a647_scdfs.assign(Metadata_Stain="A647")

common_cols = gold_scdfs.columns.intersection(dapi_scdfs.columns).intersection(a647_scdfs.columns)
scdfs = pd.concat([gold_scdfs[common_cols], dapi_scdfs[common_cols], a647_scdfs[common_cols]], axis=0)

# We are only comparing stains within treated wells
scdfs_treated = scdfs.loc[scdfs["Metadata_Condition"] != "untreated"]

# %% [markdown]
# ## Specify Feature Metadata Columns

# %%
feat_cols = scdfs.columns[~scdfs.columns.str.contains("Metadata")]

# %% [markdown]
# ## Mean Aggregation to the Well Level

# %%
# Metadata to retain
agg_funcs = {
    "Metadata_Condition": "first",
}

agg_funcs |= {feat_col: "mean" for feat_col in feat_cols}
scdfs_treated = scdfs_treated.groupby(["Metadata_Plate", "Metadata_Well", "Metadata_Stain"]).agg(agg_funcs).reset_index()

# %%
print(scdfs_treated)
# Out:
#    Metadata_Plate Metadata_Well Metadata_Stain Metadata_Condition  \
# 0          slide1            A1           A647                NTC
# 1          slide1            A1           DAPI                NTC
# 2          slide1            A1           GOLD                NTC
# 3          slide1            A2           A647            ALY kd8
# 4          slide1            A2           DAPI            ALY kd8
# ..            ...           ...            ...                ...
# 79         slide4            B2           DAPI          SARNP kd3
# 80         slide4            B2           GOLD          SARNP kd3
# 81         slide4            B3           A647        TMEM259 kd5
# 82         slide4            B3           DAPI        TMEM259 kd5
# 83         slide4            B3           GOLD        TMEM259 kd5
#
#     Nuclei_AreaShape_Area  Nuclei_AreaShape_Compactness  \
# 0                0.822930                      0.881271
# 1                0.822930                      0.881271
# 2                0.822930                      0.881271
# 3                0.597573                      0.435230
# 4                0.597573                      0.435230
# ..                    ...                           ...
# 79               0.658350                      0.217495
# 80               0.658350                      0.217495
# 81               0.665668                      0.161654
# 82               0.665668                      0.161654
# 83               0.665668                      0.161654
#
#     Nuclei_AreaShape_Eccentricity  Nuclei_AreaShape_Extent  \
# 0                        0.703645                -0.831503
# 1                        0.703645                -0.831503
# 2                        0.703645                -0.831503
# 3                        0.571900                -0.504542
# 4                        0.571900                -0.504542
# ..                            ...                      ...
# 79                       0.416887                -0.246187
# 80                       0.416887                -0.246187
# 81                       0.266971                -0.172451
# 82                       0.266971                -0.172451
# 83                       0.266971                -0.172451
#
#     Nuclei_AreaShape_FormFactor  Nuclei_AreaShape_MinFeretDiameter  ...  \
# 0                     -0.924647                           0.343261  ...
# 1                     -0.924647                           0.343261  ...
# 2                     -0.924647                           0.343261  ...
# 3                     -0.479277                           0.174930  ...
# 4                     -0.479277                           0.174930  ...
# ..                          ...                                ...  ...
# 79                    -0.280327                           0.359401  ...
# 80                    -0.280327                           0.359401  ...
# 81                    -0.205373                           0.496089  ...
# 82                    -0.205373                           0.496089  ...
# 83                    -0.205373                           0.496089  ...
#
#     Nuclei_RadialDistribution_ZernikePhase_8_8  \
# 0                                    -0.015042
# 1                                    -0.006253
# 2                                     0.006725
# 3                                    -0.000985
# 4                                     0.005417
# ..                                         ...
# 79                                    0.013770
# 80                                    0.014870
# 81                                    0.005375
# 82                                    0.020617
# 83                                    0.002695
#
#     Nuclei_RadialDistribution_ZernikePhase_9_1  \
# 0                                     0.018605
# 1                                     0.021927
# 2                                     0.008139
# 3                                     0.006110
# 4                                    -0.016053
# ..                                         ...
# 79                                   -0.001249
# 80                                   -0.005223
# 81                                   -0.013410
# 82                                   -0.007026
# 83                                   -0.009610
#
#     Nuclei_RadialDistribution_ZernikePhase_9_3  \
# 0                                    -0.058823
# 1                                    -0.075890
# 2                                    -0.054102
# 3                                     0.018343
# 4                                    -0.000847
# ..                                         ...
# 79                                    0.023444
# 80                                    0.009352
# 81                                   -0.005959
# 82                                    0.012595
# 83                                   -0.006364
#
#     Nuclei_RadialDistribution_ZernikePhase_9_5  \
# 0                                    -0.030010
# 1                                    -0.050538
# 2                                    -0.042331
# 3                                    -0.002243
# 4                                     0.018493
# ..                                         ...
# 79                                    0.017427
# 80                                    0.007195
# 81                                    0.005827
# 82                                    0.007589
# 83                                    0.008268
#
#     Nuclei_RadialDistribution_ZernikePhase_9_7  \
# 0                                    -0.012822
# 1                                    -0.030914
# 2                                     0.003489
# 3                                     0.002698
# 4                                     0.008329
# ..                                         ...
# 79                                   -0.005451
# 80                                   -0.017587
# 81                                   -0.001979
# 82                                    0.009493
# 83                                   -0.005019
#
#     Nuclei_RadialDistribution_ZernikePhase_9_9  \
# 0                                    -0.053868
# 1                                    -0.023099
# 2                                    -0.040262
# 3                                    -0.014026
# 4                                    -0.033349
# ..                                         ...
# 79                                   -0.020751
# 80                                    0.007552
# 81                                    0.006174
# 82                                    0.005480
# 83                                    0.010797
#
#     Nuclei_Texture_Correlation_3_00_256  Nuclei_Texture_Correlation_3_01_256  \
# 0                             -0.329853                            -0.279762
# 1                              0.377650                             0.403960
# 2                              0.237765                             0.097259
# 3                              0.205998                             0.206157
# 4                              0.771391                             0.715149
# ..                                  ...                                  ...
# 79                             0.371592                             0.419701
# 80                             0.295397                             0.209621
# 81                             0.077172                             0.109887
# 82                             0.517795                             0.516578
# 83                             0.428805                             0.333719
#
#     Nuclei_Texture_Correlation_3_02_256  Nuclei_Texture_Correlation_3_03_256
# 0                             -0.340624                            -0.326910
# 1                              0.409060                             0.397982
# 2                              0.193286                             0.059259
# 3                              0.231749                             0.189171
# 4                              0.782281                             0.700230
# ..                                  ...                                  ...
# 79                             0.363103                             0.357736
# 80                             0.285781                             0.178787
# 81                             0.072904                             0.124244
# 82                             0.516336                             0.522199
# 83                             0.412210                             0.342874
#
# [84 rows x 106 columns]

# %% [markdown]
# # MIC Comparisons
# Compares MIC scores between stains of the same well.

# %%
micdfs = []
speckle_stains = {"GOLD", "A647"}

for stain in speckle_stains:
    for feature_order in ("mic", "shuffled_mic"):

        if feature_order == "mic":
            mic_comparator = MIC()

        else:
            # Shuffles the samples/features depending on your perspective
            mic_comparator = ShuffledMIC()

        speckle_stain_treatedf = scdfs_treated.loc[scdfs_treated["Metadata_Stain"] != stain]

        comparer = PairwiseCompare(
            _df=speckle_stain_treatedf,
            _comparator=mic_comparator,
            _antehoc_group_cols=["Metadata_Plate", "Metadata_Well", "Metadata_Condition"],
            _posthoc_group_cols=["Metadata_Stain"],
            _feat_cols=feat_cols,
        )

        comparer.intra_comparisons()

        micdf = pd.DataFrame(mic_comparator.comparisons)
        micdf = micdf.assign(Metadata_Comparison_Type=feature_order)
        micdfs.append(micdf)

micdfs = pd.concat(micdfs, axis=0)

# %%
print(micdfs)
# Out:
#        mic_e Metadata_Plate__antehoc_group0 Metadata_Plate__antehoc_group1  \
# 0   0.863847                         slide1                         slide1
# 1   0.899994                         slide1                         slide1
# 2   0.817764                         slide1                         slide1
# 3   0.765375                         slide1                         slide1
# 4   0.872553                         slide1                         slide1
# ..       ...                            ...                            ...
# 23  0.140494                         slide4                         slide4
# 24  0.185182                         slide4                         slide4
# 25  0.098515                         slide4                         slide4
# 26  0.159566                         slide4                         slide4
# 27  0.112747                         slide4                         slide4
#
#    Metadata_Well__antehoc_group0 Metadata_Well__antehoc_group1  \
# 0                             A1                            A1
# 1                             A2                            A2
# 2                             A3                            A3
# 3                             A4                            A4
# 4                             B1                            B1
# ..                           ...                           ...
# 23                            A3                            A3
# 24                            A4                            A4
# 25                            B1                            B1
# 26                            B2                            B2
# 27                            B3                            B3
#
#    Metadata_Condition__antehoc_group0 Metadata_Condition__antehoc_group1  \
# 0                                 NTC                                NTC
# 1                             ALY kd8                            ALY kd8
# 2                           SART1 kd6                          SART1 kd6
# 3                            FIBP kd7                           FIBP kd7
# 4                             ALY kd5                            ALY kd5
# ..                                ...                                ...
# 23                          SARNP kd9                          SARNP kd9
# 24                        TMEM259 kd6                        TMEM259 kd6
# 25                         DDX39A kd1                         DDX39A kd1
# 26                          SARNP kd3                          SARNP kd3
# 27                        TMEM259 kd5                        TMEM259 kd5
#
#    Metadata_Stain__posthoc_group0 Metadata_Stain__posthoc_group1  \
# 0                            A647                           DAPI
# 1                            A647                           DAPI
# 2                            A647                           DAPI
# 3                            A647                           DAPI
# 4                            A647                           DAPI
# ..                            ...                            ...
# 23                           DAPI                           GOLD
# 24                           DAPI                           GOLD
# 25                           DAPI                           GOLD
# 26                           DAPI                           GOLD
# 27                           DAPI                           GOLD
#
#    Metadata_Comparison_Type
# 0                       mic
# 1                       mic
# 2                       mic
# 3                       mic
# 4                       mic
# ..                      ...
# 23             shuffled_mic
# 24             shuffled_mic
# 25             shuffled_mic
# 26             shuffled_mic
# 27             shuffled_mic
#
# [112 rows x 10 columns]

# %% [markdown]
# # Save Results

# %%
for stain in speckle_stains:

    pattern = f"DAPI|{re.escape(stain)}"
    stain_micdfs = micdfs.loc[micdfs["Metadata_Stain__posthoc_group0"].str.contains(pattern, regex=True) & micdfs["Metadata_Stain__posthoc_group1"].str.contains(pattern, regex=True)]
    print(stain_micdfs)

    sns.histplot(data=stain_micdfs, x="mic_e", hue="Metadata_Comparison_Type",
    palette={"shuffled_mic": 'blue', "mic": 'red'}, bins=10, kde=False)

    plt.gcf().set_size_inches(18, 10)

    plt.xlabel("MIC", fontsize=13)
    plt.ylabel("Density", fontsize=13)

    plt.xticks(fontsize=12)
    plt.yticks(fontsize=12)

    plt.title(f"Distributions of Maximal Information Coeficient (MIC)\nBetween DAPI and {stain} Features per Treated Well", fontsize=16)

    plt.savefig(distribution_figures_path / f"mic_distributions_dapi_{stain.lower()}_treated_wells.png")
    plt.close()
# Out:
#        mic_e Metadata_Plate__antehoc_group0 Metadata_Plate__antehoc_group1  \
# 0   0.903531                         slide1                         slide1
# 1   0.901174                         slide1                         slide1
# 2   0.921029                         slide1                         slide1
# 3   0.804211                         slide1                         slide1
# 4   0.950206                         slide1                         slide1
# 5   0.846902                         slide1                         slide1
# 6   0.899994                         slide1                         slide1
# 7   0.939039                         slide2                         slide2
# 8   0.950136                         slide2                         slide2
# 9   0.872375                         slide2                         slide2
# 10  0.890137                         slide2                         slide2
# 11  0.851657                         slide2                         slide2
# 12  0.870085                         slide2                         slide2
# 13  0.883450                         slide2                         slide2
# 14  0.600336                         slide3                         slide3
# 15  0.772716                         slide3                         slide3
# 16  0.873537                         slide3                         slide3
# 17  0.665266                         slide3                         slide3
# 18  0.892414                         slide3                         slide3
# 19  0.792324                         slide3                         slide3
# 20  0.563255                         slide3                         slide3
# 21  0.938028                         slide4                         slide4
# 22  0.909745                         slide4                         slide4
# 23  0.834099                         slide4                         slide4
# 24  0.911797                         slide4                         slide4
# 25  0.921029                         slide4                         slide4
# 26  0.751351                         slide4                         slide4
# 27  0.892414                         slide4                         slide4
# 0   0.143877                         slide1                         slide1
# 1   0.114048                         slide1                         slide1
# 2   0.096818                         slide1                         slide1
# 3   0.110793                         slide1                         slide1
# 4   0.107381                         slide1                         slide1
# 5   0.181577                         slide1                         slide1
# 6   0.131345                         slide1                         slide1
# 7   0.178216                         slide2                         slide2
# 8   0.154110                         slide2                         slide2
# 9   0.112712                         slide2                         slide2
# 10  0.155930                         slide2                         slide2
# 11  0.139071                         slide2                         slide2
# 12  0.182842                         slide2                         slide2
# 13  0.113345                         slide2                         slide2
# 14  0.147734                         slide3                         slide3
# 15  0.119482                         slide3                         slide3
# 16  0.143712                         slide3                         slide3
# 17  0.123476                         slide3                         slide3
# 18  0.119180                         slide3                         slide3
# 19  0.153831                         slide3                         slide3
# 20  0.161447                         slide3                         slide3
# 21  0.206268                         slide4                         slide4
# 22  0.121841                         slide4                         slide4
# 23  0.140494                         slide4                         slide4
# 24  0.185182                         slide4                         slide4
# 25  0.098515                         slide4                         slide4
# 26  0.159566                         slide4                         slide4
# 27  0.112747                         slide4                         slide4
#
#    Metadata_Well__antehoc_group0 Metadata_Well__antehoc_group1  \
# 0                             A1                            A1
# 1                             A2                            A2
# 2                             A3                            A3
# 3                             A4                            A4
# 4                             B1                            B1
# 5                             B2                            B2
# 6                             B3                            B3
# 7                             A1                            A1
# 8                             A2                            A2
# 9                             A3                            A3
# 10                            A4                            A4
# 11                            B1                            B1
# 12                            B2                            B2
# 13                            B3                            B3
# 14                            A1                            A1
# 15                            A2                            A2
# 16                            A3                            A3
# 17                            A4                            A4
# 18                            B1                            B1
# 19                            B2                            B2
# 20                            B3                            B3
# 21                            A1                            A1
# 22                            A2                            A2
# 23                            A3                            A3
# 24                            A4                            A4
# 25                            B1                            B1
# 26                            B2                            B2
# 27                            B3                            B3
# 0                             A1                            A1
# 1                             A2                            A2
# 2                             A3                            A3
# 3                             A4                            A4
# 4                             B1                            B1
# 5                             B2                            B2
# 6                             B3                            B3
# 7                             A1                            A1
# 8                             A2                            A2
# 9                             A3                            A3
# 10                            A4                            A4
# 11                            B1                            B1
# 12                            B2                            B2
# 13                            B3                            B3
# 14                            A1                            A1
# 15                            A2                            A2
# 16                            A3                            A3
# 17                            A4                            A4
# 18                            B1                            B1
# 19                            B2                            B2
# 20                            B3                            B3
# 21                            A1                            A1
# 22                            A2                            A2
# 23                            A3                            A3
# 24                            A4                            A4
# 25                            B1                            B1
# 26                            B2                            B2
# 27                            B3                            B3
#
#    Metadata_Condition__antehoc_group0 Metadata_Condition__antehoc_group1  \
# 0                                 NTC                                NTC
# 1                             ALY kd8                            ALY kd8
# 2                           SART1 kd6                          SART1 kd6
# 3                            FIBP kd7                           FIBP kd7
# 4                             ALY kd5                            ALY kd5
# 5                           SART1 kd4                          SART1 kd4
# 6                            FIBP kd6                           FIBP kd6
# 7                                 NTC                                NTC
# 8                          DDX39A kd4                         DDX39A kd4
# 9                           SARNP kd9                          SARNP kd9
# 10                        TMEM259 kd6                        TMEM259 kd6
# 11                         DDX39A kd1                         DDX39A kd1
# 12                          SARNP kd3                          SARNP kd3
# 13                        TMEM259 kd5                        TMEM259 kd5
# 14                                NTC                                NTC
# 15                            ALY kd8                            ALY kd8
# 16                          SART1 kd6                          SART1 kd6
# 17                           FIBP kd7                           FIBP kd7
# 18                            ALY kd5                            ALY kd5
# 19                          SART1 kd4                          SART1 kd4
# 20                           FIBP kd6                           FIBP kd6
# 21                                NTC                                NTC
# 22                         DDX39A kd4                         DDX39A kd4
# 23                          SARNP kd9                          SARNP kd9
# 24                        TMEM259 kd6                        TMEM259 kd6
# 25                         DDX39A kd1                         DDX39A kd1
# 26                          SARNP kd3                          SARNP kd3
# 27                        TMEM259 kd5                        TMEM259 kd5
# 0                                 NTC                                NTC
# 1                             ALY kd8                            ALY kd8
# 2                           SART1 kd6                          SART1 kd6
# 3                            FIBP kd7                           FIBP kd7
# 4                             ALY kd5                            ALY kd5
# 5                           SART1 kd4                          SART1 kd4
# 6                            FIBP kd6                           FIBP kd6
# 7                                 NTC                                NTC
# 8                          DDX39A kd4                         DDX39A kd4
# 9                           SARNP kd9                          SARNP kd9
# 10                        TMEM259 kd6                        TMEM259 kd6
# 11                         DDX39A kd1                         DDX39A kd1
# 12                          SARNP kd3                          SARNP kd3
# 13                        TMEM259 kd5                        TMEM259 kd5
# 14                                NTC                                NTC
# 15                            ALY kd8                            ALY kd8
# 16                          SART1 kd6                          SART1 kd6
# 17                           FIBP kd7                           FIBP kd7
# 18                            ALY kd5                            ALY kd5
# 19                          SART1 kd4                          SART1 kd4
# 20                           FIBP kd6                           FIBP kd6
# 21                                NTC                                NTC
# 22                         DDX39A kd4                         DDX39A kd4
# 23                          SARNP kd9                          SARNP kd9
# 24                        TMEM259 kd6                        TMEM259 kd6
# 25                         DDX39A kd1                         DDX39A kd1
# 26                          SARNP kd3                          SARNP kd3
# 27                        TMEM259 kd5                        TMEM259 kd5
#
#    Metadata_Stain__posthoc_group0 Metadata_Stain__posthoc_group1  \
# 0                            DAPI                           GOLD
# 1                            DAPI                           GOLD
# 2                            DAPI                           GOLD
# 3                            DAPI                           GOLD
# 4                            DAPI                           GOLD
# 5                            DAPI                           GOLD
# 6                            DAPI                           GOLD
# 7                            DAPI                           GOLD
# 8                            DAPI                           GOLD
# 9                            DAPI                           GOLD
# 10                           DAPI                           GOLD
# 11                           DAPI                           GOLD
# 12                           DAPI                           GOLD
# 13                           DAPI                           GOLD
# 14                           DAPI                           GOLD
# 15                           DAPI                           GOLD
# 16                           DAPI                           GOLD
# 17                           DAPI                           GOLD
# 18                           DAPI                           GOLD
# 19                           DAPI                           GOLD
# 20                           DAPI                           GOLD
# 21                           DAPI                           GOLD
# 22                           DAPI                           GOLD
# 23                           DAPI                           GOLD
# 24                           DAPI                           GOLD
# 25                           DAPI                           GOLD
# 26                           DAPI                           GOLD
# 27                           DAPI                           GOLD
# 0                            DAPI                           GOLD
# 1                            DAPI                           GOLD
# 2                            DAPI                           GOLD
# 3                            DAPI                           GOLD
# 4                            DAPI                           GOLD
# 5                            DAPI                           GOLD
# 6                            DAPI                           GOLD
# 7                            DAPI                           GOLD
# 8                            DAPI                           GOLD
# 9                            DAPI                           GOLD
# 10                           DAPI                           GOLD
# 11                           DAPI                           GOLD
# 12                           DAPI                           GOLD
# 13                           DAPI                           GOLD
# 14                           DAPI                           GOLD
# 15                           DAPI                           GOLD
# 16                           DAPI                           GOLD
# 17                           DAPI                           GOLD
# 18                           DAPI                           GOLD
# 19                           DAPI                           GOLD
# 20                           DAPI                           GOLD
# 21                           DAPI                           GOLD
# 22                           DAPI                           GOLD
# 23                           DAPI                           GOLD
# 24                           DAPI                           GOLD
# 25                           DAPI                           GOLD
# 26                           DAPI                           GOLD
# 27                           DAPI                           GOLD
#
#    Metadata_Comparison_Type
# 0                       mic
# 1                       mic
# 2                       mic
# 3                       mic
# 4                       mic
# 5                       mic
# 6                       mic
# 7                       mic
# 8                       mic
# 9                       mic
# 10                      mic
# 11                      mic
# 12                      mic
# 13                      mic
# 14                      mic
# 15                      mic
# 16                      mic
# 17                      mic
# 18                      mic
# 19                      mic
# 20                      mic
# 21                      mic
# 22                      mic
# 23                      mic
# 24                      mic
# 25                      mic
# 26                      mic
# 27                      mic
# 0              shuffled_mic
# 1              shuffled_mic
# 2              shuffled_mic
# 3              shuffled_mic
# 4              shuffled_mic
# 5              shuffled_mic
# 6              shuffled_mic
# 7              shuffled_mic
# 8              shuffled_mic
# 9              shuffled_mic
# 10             shuffled_mic
# 11             shuffled_mic
# 12             shuffled_mic
# 13             shuffled_mic
# 14             shuffled_mic
# 15             shuffled_mic
# 16             shuffled_mic
# 17             shuffled_mic
# 18             shuffled_mic
# 19             shuffled_mic
# 20             shuffled_mic
# 21             shuffled_mic
# 22             shuffled_mic
# 23             shuffled_mic
# 24             shuffled_mic
# 25             shuffled_mic
# 26             shuffled_mic
# 27             shuffled_mic
#        mic_e Metadata_Plate__antehoc_group0 Metadata_Plate__antehoc_group1  \
# 0   0.863847                         slide1                         slide1
# 1   0.899994                         slide1                         slide1
# 2   0.817764                         slide1                         slide1
# 3   0.765375                         slide1                         slide1
# 4   0.872553                         slide1                         slide1
# 5   0.848309                         slide1                         slide1
# 6   0.796102                         slide1                         slide1
# 7   0.824643                         slide2                         slide2
# 8   0.899994                         slide2                         slide2
# 9   0.950206                         slide2                         slide2
# 10  0.750161                         slide2                         slide2
# 11  0.751251                         slide2                         slide2
# 12  0.866149                         slide2                         slide2
# 13  0.792115                         slide2                         slide2
# 14  0.484561                         slide3                         slide3
# 15  0.882438                         slide3                         slide3
# 16  0.826283                         slide3                         slide3
# 17  0.767600                         slide3                         slide3
# 18  0.825814                         slide3                         slide3
# 19  0.896254                         slide3                         slide3
# 20  0.750577                         slide3                         slide3
# 21  0.773319                         slide4                         slide4
# 22  0.870085                         slide4                         slide4
# 23  0.950206                         slide4                         slide4
# 24  0.800139                         slide4                         slide4
# 25  0.872553                         slide4                         slide4
# 26  0.575839                         slide4                         slide4
# 27  0.890137                         slide4                         slide4
# 0   0.119709                         slide1                         slide1
# 1   0.127031                         slide1                         slide1
# 2   0.208707                         slide1                         slide1
# 3   0.119643                         slide1                         slide1
# 4   0.130356                         slide1                         slide1
# 5   0.187715                         slide1                         slide1
# 6   0.111779                         slide1                         slide1
# 7   0.151616                         slide2                         slide2
# 8   0.151580                         slide2                         slide2
# 9   0.143614                         slide2                         slide2
# 10  0.102983                         slide2                         slide2
# 11  0.138577                         slide2                         slide2
# 12  0.164307                         slide2                         slide2
# 13  0.166029                         slide2                         slide2
# 14  0.147165                         slide3                         slide3
# 15  0.117943                         slide3                         slide3
# 16  0.144333                         slide3                         slide3
# 17  0.134100                         slide3                         slide3
# 18  0.115205                         slide3                         slide3
# 19  0.143241                         slide3                         slide3
# 20  0.114956                         slide3                         slide3
# 21  0.155546                         slide4                         slide4
# 22  0.127402                         slide4                         slide4
# 23  0.142397                         slide4                         slide4
# 24  0.144362                         slide4                         slide4
# 25  0.102234                         slide4                         slide4
# 26  0.142851                         slide4                         slide4
# 27  0.110904                         slide4                         slide4
#
#    Metadata_Well__antehoc_group0 Metadata_Well__antehoc_group1  \
# 0                             A1                            A1
# 1                             A2                            A2
# 2                             A3                            A3
# 3                             A4                            A4
# 4                             B1                            B1
# 5                             B2                            B2
# 6                             B3                            B3
# 7                             A1                            A1
# 8                             A2                            A2
# 9                             A3                            A3
# 10                            A4                            A4
# 11                            B1                            B1
# 12                            B2                            B2
# 13                            B3                            B3
# 14                            A1                            A1
# 15                            A2                            A2
# 16                            A3                            A3
# 17                            A4                            A4
# 18                            B1                            B1
# 19                            B2                            B2
# 20                            B3                            B3
# 21                            A1                            A1
# 22                            A2                            A2
# 23                            A3                            A3
# 24                            A4                            A4
# 25                            B1                            B1
# 26                            B2                            B2
# 27                            B3                            B3
# 0                             A1                            A1
# 1                             A2                            A2
# 2                             A3                            A3
# 3                             A4                            A4
# 4                             B1                            B1
# 5                             B2                            B2
# 6                             B3                            B3
# 7                             A1                            A1
# 8                             A2                            A2
# 9                             A3                            A3
# 10                            A4                            A4
# 11                            B1                            B1
# 12                            B2                            B2
# 13                            B3                            B3
# 14                            A1                            A1
# 15                            A2                            A2
# 16                            A3                            A3
# 17                            A4                            A4
# 18                            B1                            B1
# 19                            B2                            B2
# 20                            B3                            B3
# 21                            A1                            A1
# 22                            A2                            A2
# 23                            A3                            A3
# 24                            A4                            A4
# 25                            B1                            B1
# 26                            B2                            B2
# 27                            B3                            B3
#
#    Metadata_Condition__antehoc_group0 Metadata_Condition__antehoc_group1  \
# 0                                 NTC                                NTC
# 1                             ALY kd8                            ALY kd8
# 2                           SART1 kd6                          SART1 kd6
# 3                            FIBP kd7                           FIBP kd7
# 4                             ALY kd5                            ALY kd5
# 5                           SART1 kd4                          SART1 kd4
# 6                            FIBP kd6                           FIBP kd6
# 7                                 NTC                                NTC
# 8                          DDX39A kd4                         DDX39A kd4
# 9                           SARNP kd9                          SARNP kd9
# 10                        TMEM259 kd6                        TMEM259 kd6
# 11                         DDX39A kd1                         DDX39A kd1
# 12                          SARNP kd3                          SARNP kd3
# 13                        TMEM259 kd5                        TMEM259 kd5
# 14                                NTC                                NTC
# 15                            ALY kd8                            ALY kd8
# 16                          SART1 kd6                          SART1 kd6
# 17                           FIBP kd7                           FIBP kd7
# 18                            ALY kd5                            ALY kd5
# 19                          SART1 kd4                          SART1 kd4
# 20                           FIBP kd6                           FIBP kd6
# 21                                NTC                                NTC
# 22                         DDX39A kd4                         DDX39A kd4
# 23                          SARNP kd9                          SARNP kd9
# 24                        TMEM259 kd6                        TMEM259 kd6
# 25                         DDX39A kd1                         DDX39A kd1
# 26                          SARNP kd3                          SARNP kd3
# 27                        TMEM259 kd5                        TMEM259 kd5
# 0                                 NTC                                NTC
# 1                             ALY kd8                            ALY kd8
# 2                           SART1 kd6                          SART1 kd6
# 3                            FIBP kd7                           FIBP kd7
# 4                             ALY kd5                            ALY kd5
# 5                           SART1 kd4                          SART1 kd4
# 6                            FIBP kd6                           FIBP kd6
# 7                                 NTC                                NTC
# 8                          DDX39A kd4                         DDX39A kd4
# 9                           SARNP kd9                          SARNP kd9
# 10                        TMEM259 kd6                        TMEM259 kd6
# 11                         DDX39A kd1                         DDX39A kd1
# 12                          SARNP kd3                          SARNP kd3
# 13                        TMEM259 kd5                        TMEM259 kd5
# 14                                NTC                                NTC
# 15                            ALY kd8                            ALY kd8
# 16                          SART1 kd6                          SART1 kd6
# 17                           FIBP kd7                           FIBP kd7
# 18                            ALY kd5                            ALY kd5
# 19                          SART1 kd4                          SART1 kd4
# 20                           FIBP kd6                           FIBP kd6
# 21                                NTC                                NTC
# 22                         DDX39A kd4                         DDX39A kd4
# 23                          SARNP kd9                          SARNP kd9
# 24                        TMEM259 kd6                        TMEM259 kd6
# 25                         DDX39A kd1                         DDX39A kd1
# 26                          SARNP kd3                          SARNP kd3
# 27                        TMEM259 kd5                        TMEM259 kd5
#
#    Metadata_Stain__posthoc_group0 Metadata_Stain__posthoc_group1  \
# 0                            A647                           DAPI
# 1                            A647                           DAPI
# 2                            A647                           DAPI
# 3                            A647                           DAPI
# 4                            A647                           DAPI
# 5                            A647                           DAPI
# 6                            A647                           DAPI
# 7                            A647                           DAPI
# 8                            A647                           DAPI
# 9                            A647                           DAPI
# 10                           A647                           DAPI
# 11                           A647                           DAPI
# 12                           A647                           DAPI
# 13                           A647                           DAPI
# 14                           A647                           DAPI
# 15                           A647                           DAPI
# 16                           A647                           DAPI
# 17                           A647                           DAPI
# 18                           A647                           DAPI
# 19                           A647                           DAPI
# 20                           A647                           DAPI
# 21                           A647                           DAPI
# 22                           A647                           DAPI
# 23                           A647                           DAPI
# 24                           A647                           DAPI
# 25                           A647                           DAPI
# 26                           A647                           DAPI
# 27                           A647                           DAPI
# 0                            A647                           DAPI
# 1                            A647                           DAPI
# 2                            A647                           DAPI
# 3                            A647                           DAPI
# 4                            A647                           DAPI
# 5                            A647                           DAPI
# 6                            A647                           DAPI
# 7                            A647                           DAPI
# 8                            A647                           DAPI
# 9                            A647                           DAPI
# 10                           A647                           DAPI
# 11                           A647                           DAPI
# 12                           A647                           DAPI
# 13                           A647                           DAPI
# 14                           A647                           DAPI
# 15                           A647                           DAPI
# 16                           A647                           DAPI
# 17                           A647                           DAPI
# 18                           A647                           DAPI
# 19                           A647                           DAPI
# 20                           A647                           DAPI
# 21                           A647                           DAPI
# 22                           A647                           DAPI
# 23                           A647                           DAPI
# 24                           A647                           DAPI
# 25                           A647                           DAPI
# 26                           A647                           DAPI
# 27                           A647                           DAPI
#
#    Metadata_Comparison_Type
# 0                       mic
# 1                       mic
# 2                       mic
# 3                       mic
# 4                       mic
# 5                       mic
# 6                       mic
# 7                       mic
# 8                       mic
# 9                       mic
# 10                      mic
# 11                      mic
# 12                      mic
# 13                      mic
# 14                      mic
# 15                      mic
# 16                      mic
# 17                      mic
# 18                      mic
# 19                      mic
# 20                      mic
# 21                      mic
# 22                      mic
# 23                      mic
# 24                      mic
# 25                      mic
# 26                      mic
# 27                      mic
# 0              shuffled_mic
# 1              shuffled_mic
# 2              shuffled_mic
# 3              shuffled_mic
# 4              shuffled_mic
# 5              shuffled_mic
# 6              shuffled_mic
# 7              shuffled_mic
# 8              shuffled_mic
# 9              shuffled_mic
# 10             shuffled_mic
# 11             shuffled_mic
# 12             shuffled_mic
# 13             shuffled_mic
# 14             shuffled_mic
# 15             shuffled_mic
# 16             shuffled_mic
# 17             shuffled_mic
# 18             shuffled_mic
# 19             shuffled_mic
# 20             shuffled_mic
# 21             shuffled_mic
# 22             shuffled_mic
# 23             shuffled_mic
# 24             shuffled_mic
# 25             shuffled_mic
# 26             shuffled_mic
# 27             shuffled_mic

# %%
micdfs.to_parquet(mic_comparisons_path / "treated_well_sirna_mic_comparisons.parquet")
