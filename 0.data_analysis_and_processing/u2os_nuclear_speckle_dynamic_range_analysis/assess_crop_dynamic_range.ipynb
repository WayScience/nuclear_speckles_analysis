# %% [markdown]
# # Assess U2OS Crop Dynamic Range
#
# Run the `nbconverted` analysis script from this notebook entrypoint.

# %%
import pathlib

cwd = pathlib.Path.cwd().resolve()
if (cwd / '.git').is_dir():
    root_dir = cwd
else:
    root_dir = None
    for parent in cwd.parents:
        if (parent / '.git').is_dir():
            root_dir = parent
            break

if root_dir is None:
    raise FileNotFoundError('No Git root directory found.')

script_path = root_dir / '0.data_analysis_and_processing/u2os_nuclear_speckle_dynamic_range_analysis/nbconverted/assess_crop_dynamic_range.py'
exec(compile(script_path.read_text(), str(script_path), 'exec'), {'__name__': '__main__'})
